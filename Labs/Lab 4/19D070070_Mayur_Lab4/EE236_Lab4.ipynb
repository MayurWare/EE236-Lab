# %%
import matplotlib.pyplot as plt

# %%
x = [35, 45, 55, 65, 75]
ff = [0.5156, 0.4947, 0.4726, 0.4509, 0.4287]

a1 = [0.292424, 0.265152, 0.239394, 0.210606, 0.182609]
a2 = [0.348485, 0.322727, 0.292424, 0.266667, 0.24058]   
a3 = [0.433333, 0.407576, 0.380303, 0.35303, 0.328986]

b = [0.3925, 0.367955, 0.343441, 0.319038, 0.294414]

# plt.plot(x,ff,"bo--")
# plt.title("Fill Factor (FF) vs Temperature")
# plt.ylabel("Fill Factor")
# plt.xlabel("Temperature (in 0C)")
# plt.savefig("ff")

# plt.plot(x,a1, "ko--",label="Id = 1mA")
# plt.plot(x,a2,"bo--",label="Id = 2mA")
# plt.plot(x,a3,"go--",label="Id = 5mA")
# plt.title("Vd vs Temperature for Id = 50uA, 1mA and 5mA")
# plt.ylabel("Vd (in V)")
# plt.xlabel("Temperature (in 0C)")
# plt.legend()
# plt.savefig("vd_temp")

plt.plot(x,ff,"bo--")
plt.title("Voc vs Temperature")
plt.ylabel("Voc")
plt.xlabel("Temperature (in 0C)")
plt.savefig("voc_temp")

# %%
Rs = [0, 10, 30]
Isc= [-0.00798276, -0.00789655, -0.00756897]
Voc = [0.420526, 0.412152, 0.396867]
FF = [0.6402, 0.5319, 0.3694]

# plt.plot(Rs,FF,"bo--")
# plt.title("Fill Factor (FF) vs Rs (in Ohm)")
# plt.ylabel("Fill Factor (FF)")
# plt.xlabel("Rs (in Ohm)")
# plt.savefig("part3_3")

Rsh = [100, 500, 5000]
Isc= [-0.00718548, -0.00780172, -0.00796552]
Voc = [0.377045, 0.409367, 0.41443]
FF = [0.4121, 0.5187, 0.5414]

plt.plot(Rsh,Voc,"bo--")
plt.title("Voc (in V) vs Rsh (in Ohm)")
plt.ylabel("Voc (in V)")
plt.xlabel("Rsh (in Ohm)")
plt.savefig("part3_2_2")
